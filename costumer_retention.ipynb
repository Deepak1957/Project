# %%
import pandas as pd

import pandas.plotting as  pl

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('datasheet.xlsx')

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %%
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      1                    1
# 1                      0                    0
# 2                      0                    0
# 3                      1                    0
# 4                      0                    0
#
#    3 Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                                  1
# 1                                                  5
# 2                                                 23
# 3                                                 11
# 4                                                 31
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           3
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.327138             1.330855
# std                 0.470042             1.183774
# min                 0.000000             0.000000
# 25%                 0.000000             0.000000
# 50%                 0.000000             1.000000
# 75%                 1.000000             2.000000
# max                 1.000000             4.000000
#
#        3 Which city do you shop online from?  \
# count                             269.000000
# mean                                4.494424
# std                                 3.187687
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 4.000000
# 75%                                 7.000000
# max                                10.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# ...

# %% [markdown]
# # Univerate

# %%
sns.distplot(df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='Density'>

# %%
df['1Gender of respondent'].value_counts()
# Out:
# 0    181
# 1     88
# Name: 1Gender of respondent, dtype: int64

# %%
sns.countplot(df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %%
sns.countplot(df['3 Which city do you shop online from?'])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
sns.distplot(df['3 Which city do you shop online from?'])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='Density'>

# %%
sns.countplot(df['4 What is the Pin Code of where you shop online from?'])
# Out:
# <AxesSubplot:xlabel='4 What is the Pin Code of where you shop online from?', ylabel='count'>

# %%
sns.distplot(df['4 What is the Pin Code of where you shop online from?'])
# Out:
# <AxesSubplot:xlabel='4 What is the Pin Code of where you shop online from?', ylabel='Density'>

# %%
sns.countplot(df['5 Since How Long You are Shopping Online ?'])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
sns.distplot(df['5 Since How Long You are Shopping Online ?'])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='Density'>

# %%
sns.countplot(df['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
sns.distplot(df['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='Density'>

# %%
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
sns.distplot(df['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='Density'>

# %%
sns.distplot(df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='Density'>

# %%
sns.countplot(df['Longer time to get logged in (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer time to get logged in (promotion, sales period)', ylabel='count'>

# %%
sns.distplot(df['Longer time to get logged in (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer time to get logged in (promotion, sales period)', ylabel='Density'>

# %%
sns.countplot(df['Longer time in displaying graphics and photos (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer time in displaying graphics and photos (promotion, sales period)', ylabel='count'>

# %%
sns.distplot(df['Longer time in displaying graphics and photos (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer time in displaying graphics and photos (promotion, sales period)', ylabel='Density'>

# %%
sns.countplot(df['Late declaration of price (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Late declaration of price (promotion, sales period)', ylabel='count'>

# %%
sns.distplot(df['Late declaration of price (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Late declaration of price (promotion, sales period)', ylabel='Density'>

# %%
sns.countplot(df['Longer page loading time (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer page loading time (promotion, sales period)', ylabel='count'>

# %%
sns.distplot(df['Longer page loading time (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer page loading time (promotion, sales period)', ylabel='Density'>

# %%
sns.countplot(df['Limited mode of payment on most products (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Limited mode of payment on most products (promotion, sales period)', ylabel='count'>

# %%
sns.distplot(df['Limited mode of payment on most products (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Limited mode of payment on most products (promotion, sales period)', ylabel='Density'>

# %%
sns.countplot(df['Limited mode of payment on most products (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Limited mode of payment on most products (promotion, sales period)', ylabel='count'>

# %%
sns.distplot(df['Frequent disruption when moving from one page to another'])
# Out:
# <AxesSubplot:xlabel='Frequent disruption when moving from one page to another', ylabel='Density'>

# %%
sns.countplot(df['Website is as efficient as before'])
# Out:
# <AxesSubplot:xlabel='Website is as efficient as before', ylabel='count'>

# %%
sns.distplot(df['Website is as efficient as before'])
# Out:
# <AxesSubplot:xlabel='Website is as efficient as before', ylabel='Density'>

# %%
sns.countplot(df['Which of the Indian online retailer would you recommend to a friend?'])
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='count'>

# %%
sns.distplot(df['Which of the Indian online retailer would you recommend to a friend?'])
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='Density'>

# %%
df.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                               0.046169
# 3 Which city do you shop online from?                            0.080912
# 4 What is the Pin Code of where you shop online...              -0.289628
# 5 Since How Long You are Shopping Online ?                      -0.057096
# ...                                                                   ...
# Longer delivery period                                           0.060838
# Change in website/Application design                            -0.164818
# Frequent disruption when moving from one page t...              -0.256638
# Website is as efficient as before                                0.055663
# Which of the Indian online retailer would you r...              -0.003372
#
#                                                     2 How old are you?   \
# ...

# %%
plt.figure(figsize = (72,72))
sns.heatmap(df.corr(),annot = True, fmt = ".0%")
# Out:
# <AxesSubplot:>
